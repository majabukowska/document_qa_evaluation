# %%
# %run 02_embeddings_and_search.ipynb
# Out:
# Batches: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  6.53it/s]

# %%
k = 3
context = "\n\n".join(texts[idx] for idx in top_indices[:k])
print(context[:800])
# Out:
# torch.nn — PyTorch 2.9 documentation
# Opens in a new window Opens an external website Opens an external website in a new window       <!---->Close this dialog<!---->         to enable essential site functionality, as well as for analytics, personalization, and targeted advertising. To learn more, view the following link:                                    <!---->Close Cookie Preferences<!---->
#
#
#
#  the Basics
# PyTorch Recipes
# Intro to PyTorch - YouTube Series
# Webinars
# Community
# Landscape
# Join the Ecosystem
# Community Hub
# Forums
# Developer Resources
# Contributor Awards
# Community Events
# PyTorch Ambassadors
# Projects
# PyTorch
# vLLM
# DeepSpeed
# Host Your Project
# Docs
# PyTorch
# Domains
# Blogs & News
# Blog
# Announcements
# Case Studies
# Events
# Newsletter
# About
# PyTorch Foundation
# Members
# Governing Board
# Technical A

# %%
prompt = f"""
Answer the question using ONLY the context below.
If the answer is not in the context, say "I don't know".

Context:
{context}

Question:
What is torch.nn.Module?
"""

# %%
response = call_llm(prompt) #todo
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 response = call_llm(prompt)
#       2 print(response)
#
# NameError: name 'call_llm' is not defined
