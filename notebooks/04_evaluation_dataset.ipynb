# %%
# %run 02_embeddings_and_search.ipynb
# Out:
# Batches: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.99it/s]

# %%
questions = [
    "What is torch.nn.Module?",
    "What are Dropout Layers?",
    "What are Transformer Layers in torch.nn?",
    "What is torch.utils.data used for?",
    "How does torch.nn compare to TensorFlow?",
]

# %%
evaluation_data = []

k = 3

for question in questions:
    top_indices = retrieve(question, k=k)
    context = "\n\n".join(texts[idx] for idx in top_indices)

    print("QUESTION:")
    print(question)
    print("\nCONTEXT:")
    print(context[:800])
    print("\n" + "-"*80)
# Out:
# QUESTION:
# What is torch.nn.Module?
#
# CONTEXT:
# Rate this Page
# ★
# ★
# ★
# ★
# ★
# torch.nn
# #
# Created On: Dec 23, 2016 | Last Updated On: Jul 25, 2025
# These are the basic building blocks for graphs:
# torch.nn
# Containers
# Convolution Layers
# Pooling layers
# Padding Layers
# Non-linear Activations (weighted sum, nonlinearity)
# Non-linear Activations (other)
# Normalization Layers
# Recurrent Layers
# Transformer Layers
# Linear Layers
# Dropout Layers
# Sparse Layers
# Distance Functions
# Loss Functions
# Vision Layers
# Shuffle Layers
# DataParallel Layers (multi-GPU, distributed)
# Utilities
# Quantized Functions
# Lazy Modules Initialization
# Buffer
# A kind of Tensor that should not be considered a model parameter.
# Parameter
# A kind of Tensor that is to be considered a module parameter.
# UninitializedParameter
# A parameter that is not initialized.
# UninitializedBuffer
# A buffer that is
#
# ...
